# %%
import numpy as np
import pandas as pd
df = pd.read_csv("student or staff profiles.csv")
df
# Out:
#      entity_id                name     role                email department  \
# 0      E100000          Neha Mehta  student     user0@campus.edu      CIVIL
# 1      E100001          Neha Kumar  student     user1@campus.edu    Physics
# 2      E100002          Neha Singh  student     user2@campus.edu      Admin
# 3      E100003        Ishaan Desai  student     user3@campus.edu      Admin
# 4      E100004         Rohan Desai  student     user4@campus.edu       MECH
# ...        ...                 ...      ...                  ...        ...
# 6995   E106995  Siddharth Malhotra  faculty  user6995@campus.edu  Chemistry
# 6996   E106996         Divya Kumar  student  user6996@campus.edu       MECH
# 6997   E106997         Aarav Kumar  student  user6997@campus.edu        ECE
# 6998   E106998           Neha Iyer  student  user6998@campus.edu    Physics
# 6999   E106999          Sana Mehta  student  user6999@campus.edu        BIO
#
# ...

# %% [markdown]
# ## df is ORIGINAL UNTOUCHED DATAFRAME ##

# %%
ndf = df
ndf['person_id']=ndf['student_id'].fillna(df['staff_id'])
ndf = ndf[['entity_id','name','role','email','department','person_id','card_id','device_hash','face_id']]
ndf['has_face_id'] = ndf['face_id'].notna()
ndf
# Out:
# C:\Users\anubh\AppData\Local\Temp\ipykernel_22880\2872267820.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndf['has_face_id'] = ndf['face_id'].notna()
#      entity_id                name     role                email department  \
# 0      E100000          Neha Mehta  student     user0@campus.edu      CIVIL
# 1      E100001          Neha Kumar  student     user1@campus.edu    Physics
# 2      E100002          Neha Singh  student     user2@campus.edu      Admin
# 3      E100003        Ishaan Desai  student     user3@campus.edu      Admin
# 4      E100004         Rohan Desai  student     user4@campus.edu       MECH
# ...        ...                 ...      ...                  ...        ...
# ...

# %% [markdown]
# ## ndf is the DATAFRAME WITH SINGLE COLUMN FOR STUDENT/STAFF_ID AND IT HAS A SEPARATE COLUMN INDICATING WHETHER FACE_ID IS PRESENT OR NOT ##

# %%
nndf = ndf[ndf['has_face_id'] == False]
nndf.head()
# Out:
#      entity_id           name     role                email department  \
# 5000   E105000     Ananya Rao  student  user5000@campus.edu      Admin
# 5001   E105001     Neha Kumar  student  user5001@campus.edu        BIO
# 5002   E105002    Priya Desai    staff  user5002@campus.edu      Admin
# 5003   E105003    Aarav Gupta  student  user5003@campus.edu        ECE
# 5004   E105004  Neha Malhotra  student  user5004@campus.edu    Physics
#
#      person_id card_id     device_hash face_id  has_face_id
# 5000    S69064   C1869  DH5376bde61359     NaN        False
# 5001    S83223   C2635  DH68903a538679     NaN        False
# 5002     T5205   C8611  DHaec7bc536843     NaN        False
# 5003    S53530   C5040  DH6b52004ba398     NaN        False
# 5004    S28159   C6585  DHc508b91c059c     NaN        False

# %% [markdown]
# ## nndf is the DATAFRAME ONLY CONTAINING ENTITIES WITH false HAS_FACE_ID ##
