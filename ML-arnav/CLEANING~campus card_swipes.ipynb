# %%
import numpy as np
import pandas as pd
df = pd.read_csv("campus card_swipes.csv")
df
# Out:
#      card_id  location_id            timestamp
# 0      C7151          GYM  2025-09-13 14:02:40
# 1      C4562  ADMIN_LOBBY  2025-09-22 00:16:08
# 2      C6840      LIB_ENT  2025-09-12 22:50:40
# 3      C4515   AUDITORIUM  2025-08-29 22:40:16
# 4      C9537      LIB_ENT  2025-09-15 21:56:08
# ...      ...          ...                  ...
# 7995   C2425      LAB_305  2025-09-23 20:37:24
# 7996   C1585      LIB_ENT  2025-09-22 15:29:48
# 7997   C9114   AUDITORIUM  2025-09-19 11:24:01
# 7998   C3278       CAF_01  2025-09-21 18:22:58
# 7999   C6899  HOSTEL_GATE  2025-09-12 13:25:35
#
# [8000 rows x 3 columns]

# %% [markdown]
# ## df is the ORIGINAL UNTOUCHED DATAFRAME ##

# %%
ndf = df
ndf['timestamp']=pd.to_datetime(ndf['timestamp'])
ndf['month'] = ndf['timestamp'].dt.month
ndf['month_name'] = ndf['timestamp'].dt.month_name()
ndf['day_of_week'] = ndf['timestamp'].dt.dayofweek
ndf['day_name'] = ndf['timestamp'].dt.day_name()
ndf['hour'] = ndf['timestamp'].dt.hour
ndf['minute'] = ndf['timestamp'].dt.minute
ndf['second'] = ndf['timestamp'].dt.second
ndf
# Out:
#      card_id  location_id           timestamp  month month_name  day_of_week  \
# 0      C7151          GYM 2025-09-13 14:02:40      9  September            5
# 1      C4562  ADMIN_LOBBY 2025-09-22 00:16:08      9  September            0
# 2      C6840      LIB_ENT 2025-09-12 22:50:40      9  September            4
# 3      C4515   AUDITORIUM 2025-08-29 22:40:16      8     August            4
# 4      C9537      LIB_ENT 2025-09-15 21:56:08      9  September            0
# ...      ...          ...                 ...    ...        ...          ...
# 7995   C2425      LAB_305 2025-09-23 20:37:24      9  September            1
# 7996   C1585      LIB_ENT 2025-09-22 15:29:48      9  September            0
# 7997   C9114   AUDITORIUM 2025-09-19 11:24:01      9  September            4
# 7998   C3278       CAF_01 2025-09-21 18:22:58      9  September            6
# 7999   C6899  HOSTEL_GATE 2025-09-12 13:25:35      9  September            4
#
#       day_name  hour  minute  second
# 0     Saturday    14       2      40
# 1       Monday     0      16       8
# 2       Friday    22      50      40
# 3       Friday    22      40      16
# 4       Monday    21      56       8
# ...        ...   ...     ...     ...
# 7995   Tuesday    20      37      24
# 7996    Monday    15      29      48
# 7997    Friday    11      24       1
# 7998    Sunday    18      22      58
# 7999    Friday    13      25      35
#
# [8000 rows x 10 columns]

# %% [markdown]
# ## ndf is the MODIFIED DATAFRAME WITH PROPER DATETIME ALIGNMENT ##
