# %%
import numpy as np
import pandas as pd
df = pd.read_csv("free_text_notes (helpdesk or RSVPs).csv")
df
# Out:
#       note_id entity_id     category  \
# 0     N400000   E101498         rsvp
# 1     N400001   E101738     helpdesk
# 2     N400002   E101590  maintenance
# 3     N400003   E101144     feedback
# 4     N400004   E102891     incident
# ...       ...       ...          ...
# 6995  N406995   E100481  maintenance
# 6996  N406996   E100278     feedback
# 6997  N406997   E105224     feedback
# 6998  N406998   E101619  maintenance
# 6999  N406999   E105461     incident
#
#                                              text            timestamp
# 0     Confirmed attendance for robotics workshop.  2025-08-30 02:51:39
# 1              Wi-Fi not working in hostel block.  2025-09-18 03:03:05
# 2                  CCTV near library needs check.  2025-09-06 19:47:08
# 3                   Broken chair in seminar room.  2025-09-19 09:05:20
# 4              Wi-Fi not working in hostel block.  2025-09-11 13:28:20
# ...                                           ...                  ...
# ...

# %% [markdown]
# ## df is the ORIGINAL UNTOUCHED DATAFRAME ##

# %%
ndf = df
ndf['timestamp']=pd.to_datetime(ndf['timestamp'])
ndf['month'] = ndf['timestamp'].dt.month
ndf['month_name'] = ndf['timestamp'].dt.month_name()
ndf['day_of_week'] = ndf['timestamp'].dt.dayofweek
ndf['day_name'] = ndf['timestamp'].dt.day_name()
ndf['hour'] = ndf['timestamp'].dt.hour
ndf['minute'] = ndf['timestamp'].dt.minute
ndf['second'] = ndf['timestamp'].dt.second
ndf
# Out:
#       note_id entity_id     category  \
# 0     N400000   E101498         rsvp
# 1     N400001   E101738     helpdesk
# 2     N400002   E101590  maintenance
# 3     N400003   E101144     feedback
# 4     N400004   E102891     incident
# ...       ...       ...          ...
# 6995  N406995   E100481  maintenance
# 6996  N406996   E100278     feedback
# 6997  N406997   E105224     feedback
# 6998  N406998   E101619  maintenance
# 6999  N406999   E105461     incident
#
#                                              text           timestamp  month  \
# 0     Confirmed attendance for robotics workshop. 2025-08-30 02:51:39      8
# 1              Wi-Fi not working in hostel block. 2025-09-18 03:03:05      9
# 2                  CCTV near library needs check. 2025-09-06 19:47:08      9
# 3                   Broken chair in seminar room. 2025-09-19 09:05:20      9
# 4              Wi-Fi not working in hostel block. 2025-09-11 13:28:20      9
# ...

# %% [markdown]
# ## ndf is the MODIFIED DATAFRAME WITH PROPER DATETIME ALIGNMENT ##
